# %% [markdown]
# # Linear Regression to check the Co-relation between Water temperature and Salinity

# %% [markdown]
# CalCOFI: Over 60 years of oceanographic data: Is there a relationship between water salinity & water temperature? Can you predict the water temperature based on salinity?

# %%
import pandas as pd
import numpy as np

# %%
bottle_data = pd.read_csv('bottle.csv')
cast_data = pd.read_csv('cast.csv')
# Out:
# C:\Users\vijay\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (47,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\vijay\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bottle_data.head()
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1        1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2        1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3        1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4        1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
#
#    Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  ...  R_PHAEO  R_PRES  \
# 0       0   10.50  33.440     NaN  25.649    NaN  ...      NaN       0
# 1       8   10.46  33.440     NaN  25.656    NaN  ...      NaN       8
# 2      10   10.46  33.437     NaN  25.654    NaN  ...      NaN      10
# 3      19   10.45  33.420     NaN  25.643    NaN  ...      NaN      19
# 4      20   10.45  33.421     NaN  25.643    NaN  ...      NaN      20
#
#    R_SAMP  DIC1  DIC2  TA1  TA2  pH2  pH1  DIC Quality Comment
# ...

# %%
cast_data.head()
# Out:
#    Cst_Cnt          Cruise_ID  Cruise        Cruz_Sta  DbSta_ID  \
# 0        1  1949-03-01-C-31CR  194903  19490305400560   5400560
# 1        2  1949-03-01-C-31CR  194903  19490305200750   5200750
# 2        3  1949-03-01-C-31CR  194903  19490305100850   5100850
# 3        4  1949-03-01-C-31CR  194903  19490305000950   5000950
# 4        5  1949-03-01-C-31CR  194903  19490305001040   5001040
#
#                           Cast_ID       Sta_ID  Quarter Sta_Code  Distance  \
# 0  19-4903CR-HY-060-0930-05400560  054.0 056.0        1      NST       NaN
# 1  19-4903CR-HY-060-2112-05200750  052.0 075.0        1      NST       NaN
# 2  19-4903CR-HY-061-0354-05100850  051.0 085.0        1      NST       NaN
# 3  19-4903CR-HY-061-1042-05000950  050.0 095.0        1      NST       NaN
# 4  19-4903CR-HY-061-1706-05001040  050.0 104.0        1      NST       NaN
#
#    ... Wave_Prd  Wind_Dir  Wind_Spd  Barometer  Dry_T Wet_T  Wea  Cloud_Typ  \
# ...

# %%
bottle_data.describe()
# Out:
#              Cst_Cnt        Btl_Cnt         Depthm         T_degC  \
# count  864863.000000  864863.000000  864863.000000  853900.000000
# mean    17138.790958  432432.000000     226.831951      10.799677
# std     10240.949817  249664.587267     316.050259       4.243825
# min         1.000000       1.000000       0.000000       1.440000
# 25%      8269.000000  216216.500000      46.000000       7.680000
# 50%     16848.000000  432432.000000     125.000000      10.060000
# 75%     26557.000000  648647.500000     300.000000      13.880000
# max     34404.000000  864863.000000    5351.000000      31.140000
#
#               Salnty         O2ml_L         STheta          O2Sat  \
# count  817509.000000  696201.000000  812174.000000  661274.000000
# mean       33.840350       3.392468      25.819394      57.103779
# std         0.461843       2.073256       1.167787      37.094137
# min        28.431000      -0.010000      20.934000      -0.100000
# ...

# %%
bottle_data.shape
# Out:
# (864863, 74)

# %%
temp_salnty = bottle_data[['T_degC','Salnty']]
temp_salnty
# Out:
#         T_degC   Salnty
# 0       10.500  33.4400
# 1       10.460  33.4400
# 2       10.460  33.4370
# 3       10.450  33.4200
# 4       10.450  33.4210
# ...        ...      ...
# 864858  18.744  33.4083
# 864859  18.744  33.4083
# 864860  18.692  33.4150
# 864861  18.161  33.4062
# 864862  17.533  33.3880
#
# [864863 rows x 2 columns]

# %%
temp_salnty = temp_salnty.dropna(axis=0,how='any')

# %%
temp_salnty
# Out:
#         T_degC   Salnty
# 0       10.500  33.4400
# 1       10.460  33.4400
# 2       10.460  33.4370
# 3       10.450  33.4200
# 4       10.450  33.4210
# ...        ...      ...
# 864858  18.744  33.4083
# 864859  18.744  33.4083
# 864860  18.692  33.4150
# 864861  18.161  33.4062
# 864862  17.533  33.3880
#
# [814247 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(temp_salnty['T_degC'],temp_salnty['Salnty'], alpha=0.8)
plt.xlabel('Water Temperature')
plt.ylabel('Water Salinity')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_scaled = scaler.fit_transform(temp_salnty)

# %%
X = data_scaled[:,0]
Y = data_scaled[:,1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

# %%
reg_model = lr.fit(X_train,Y_train)

# %%
Y_pred = reg_model.predict(X_test)

# %%
plt.scatter(X_train,Y_train,color='red',alpha = 0.7)
plt.scatter(X_test,Y_pred, color='blue')
plt.xlabel('Water Temperature')
plt.ylabel('Water Salinity')
# Out:
# Text(0, 0.5, 'Water Salinity')

# %%
plt.scatter(X_test,Y_test,color='red',alpha = 0.7)
plt.scatter(X_test,Y_pred, color='blue')
plt.xlabel('Water Temperature')
plt.ylabel('Water Salinity')
# Out:
# Text(0, 0.5, 'Water Salinity')

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, Y_pred)
# Out:
# 0.25536870939116485

# %%
import seaborn as sns
c = bottle_data.corr()
sns.heatmap(c)
